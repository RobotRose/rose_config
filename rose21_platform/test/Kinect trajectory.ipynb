# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import *
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# print pd.version.version

import datetime

datadir = "/home/osch/odometry_measurements/measurement_2015_02_09_09_40/"

from odometry_test import OdomAnalyzer

# %%
ground_truth_tf = pd.read_csv(datadir+"TF-robot_marker_1-robot_marker_1_start.csv")

# %%
plt.title("Kinect trajectory")

plt.plot(ground_truth_tf["tf.pos.x"], ground_truth_tf["tf.pos.y"], label="Kinect Trajectory")
# axes.set_aspect("equal")

plt.show()
